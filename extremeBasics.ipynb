# %%
def indexOf(s:str,c:str) -> int:  # same as find
    if c not in s:
        return -1
    return s.index(c)


print(indexOf("cat","c"))

print("caat".find("c"))

print("a".upper())
print("a".isupper())

print("1".isdigit())
print("a".isdigit())

print("\'10ab\'.isalnum()","10".isalnum())
print("/".isalnum())
print("".isalnum())

print("\'10\'.isdecimal()","10".isdecimal())
print("a".isdecimal())

print(chr(97),ord("a"))
print(chr(122),ord("z"))
print(chr(65),ord("A"))
print(chr(90),ord("Z"))
print(chr(32),ord(" "))

for i in range(91,97):
    print(chr(i))
# Out:
# 0
# 0
# A
# False
# True
# False
# '10ab'.isalnum() True
# False
# False
# '10'.isdecimal() True
# False
# a 97
# z 122
# A 65
# Z 90
#   32
# [
# \
# ]
# ^
# _
# `

# %%
def bsL(arr,tar):
    s,e = 0, len(arr)-1
    while(s<=e):
        m = s + (e-s)//2
        
        if arr[m] == tar:
            e = m - 1
        elif arr[m]<tar:
            s = m + 1
        else:
            e = m - 1
            
    if s in range(0,len(arr)) and arr[s] == tar:
        return s
    else:
        return -1

def bsR(arr,tar):
    s,e = 0, len(arr)-1
    ans = -1
    while(s<=e):
        m = s + (e-s)//2
        
        if arr[m] == tar:
            s = m + 1
        elif arr[m]<tar:
            s = m + 1
        else:
            e = m - 1
            
    if e in range(0,len(arr)) and arr[e] == tar:
        return e
    else:
        return -1

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],3))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],3))

print()

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],0))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],0))
print()

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],5))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],5))
# print()
# Out:
# 3
# 13
#
# -1
# -1
#
# -1
# -1

# %%
def bsL(arr,tar):
    s,e = 0, len(arr)-1
    ans = -1
    while(s<=e):
        m = s + (e-s)//2
        
        if arr[m] == tar:
            ans = m
            e = m - 1
        elif arr[m]<tar:
            s = m + 1
        else:
            e = m - 1

    return ans

def bsR(arr,tar):
    s,e = 0, len(arr)-1
    ans = -1
    while(s<=e):
        m = s + (e-s)//2
        
        if arr[m] == tar:
            ans = m
            s = m + 1
        elif arr[m]<tar:
            s = m + 1
        else:
            e = m - 1
            
    return ans

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],3))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],3))

print()

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],0))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],0))
print()

print(bsL([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],5))
print(bsR([1,2,2,3,3,3,3,3,3,3,3,3,3,3,4],5))
# print()
# Out:
# 3
# 13
#
# -1
# -1
#
# -1
# -1
